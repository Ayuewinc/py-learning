# %%
# !pip3 install numpy
# !pip3 install pandas
# !pip3 install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 12.2 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 12.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 12.8 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 13.8 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 13.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.3/229.3 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 12.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 4.0 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1 dimension array
array1 = [1, 2, 3, 4, 5]
array2 = np.arange(0, 20, 2)
array3 = np.linspace(-5, 5, 101)
array4 = np.random.rand(10)
array5 = np.random.randint(0 ,100, 10)
array6 = np.random.normal(50, 10, 10)
print('array6: {} is here and array5: {} is here'.format(array6, array5))
# Out:
# array6: [45.45366564 49.60786132 45.21646962 42.32866091 52.33018208 45.07128286
#  64.71015841 60.22052107 55.55432288 51.93910614] is here and array5: [26 90 90 41 31 32 26 23 66 85] is here

# %%
# 2 dimension array
array7 = [[1, 2, 3], [4, 5, 6]]
array8 = np.zeros((3, 4))
array9 = np.ones((3, 4))
array10 = np.full((3, 4), 10)
array11 = np.eye(4, 4)
array12 = np.arange(1, 7).reshape((2, 3))
array13 = np.random.rand(3, 4)
array14 = np.random.randint(1, 100, (3, 4))

array14
# Out:
# array([[94, 49, 68, 86],
#        [85, 11, 93, 10],
#        [91, 36, 26, 43]])

# %%
# Multi dimension array
array15 = np.random.randint(1, 100, (3, 4, 5))
array16 = np.arange(1, 25).reshape(2, 3, 4 )
array17 = np.random.randint(1, 100, (4, 6)).reshape(2, 3, 4)
array18 = plt.imread('../a.jpeg')

array18
# Out:
# array([[[ 94, 120,   2],
#         [ 94, 120,   2],
#         [ 94, 120,   2],
#         ...,
#         [ 85, 118,   0],
#         [ 85, 118,   0],
#         [ 85, 118,   0]],
#
#        [[ 94, 120,   2],
#         [ 94, 120,   2],
#         [ 94, 120,   2],
#         ...,
#         [ 85, 118,   0],
#         [ 85, 118,   0],
#         [ 85, 118,   0]],
#
#        [[ 94, 120,   2],
#         [ 94, 120,   2],
#         [ 94, 120,   2],
#         ...,
#         [ 85, 118,   0],
#         [ 85, 118,   0],
#         [ 85, 118,   0]],
#
#        ...,
#
#        [[ 77,  95,  12],
#         [ 77,  95,  12],
#         [ 77,  95,  12],
#         ...,
#         [ 82, 119,   2],
#         [ 82, 119,   2],
#         [ 82, 119,   2]],
#
#        [[ 77,  95,  12],
#         [ 77,  95,  12],
#         [ 77,  95,  12],
#         ...,
#         [ 82, 119,   2],
#         [ 82, 119,   2],
#         [ 82, 119,   2]],
#
#        [[ 77,  95,  12],
#         [ 77,  95,  12],
#         [ 77,  95,  12],
# ...

# %%
# array index and slice
array23 = np.arange(1, 10)
# print(array25[0], array25[array25.size - 1])
# print(array25[-array25.size], array25[-1])

array24 = np.arange(1, 10).reshape(3, 3)
print(array24[2])
print(array24[0][0], array24[-1][-1])
print(array24[1][1], array24[1, 1])
array24[1][1] = 10
print(array24)
array24[1] = [10, 11, 12]
print(array24)
# Out:
# [7 8 9]
# 1 9
# 5 5
# [[ 1  2  3]
#  [ 4 10  6]
#  [ 7  8  9]]
# [[ 1  2  3]
#  [10 11 12]
#  [ 7  8  9]]

# %%
# fancy index
array25 = np.array([50, 30, 15, 20, 40])
array25[[0, 1, -1]]
array27 = array25[::-1]
print('array27:', array27)

array26 = np.array([[30, 20, 10], [40, 60, 50], [10, 90, 80]])
array26[[0, 2]]
array26[:,::-1]
# Out:
# array27: [40 20 15 30 50]
# array([[10, 20, 30],
#        [50, 60, 40],
#        [80, 90, 10]])

# %%
image_array = plt.imread('../a.jpeg')
plt.imshow(image_array)

# %%
updown_image = image_array[::-1]
plt.imshow(updown_image)

# %%
leftright_image = image_array[:,::-1]
plt.imshow(leftright_image)

# %%
cut_image = image_array[50:350, 300:500]
plt.imshow(cut_image)

# %%
# array operation
array31 = np.arange(1, 7)
array31.dump('array31_data')

array32 = np.load('array31_data', allow_pickle=True)
array32 = array31.reshape(2, 3)
array32.transpose()
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])
